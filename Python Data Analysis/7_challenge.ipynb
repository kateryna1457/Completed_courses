# %%
import zipfile
import pandas as pd
import numpy as np
import matplotlib.pyplot as pp

# %%
pd.options.display.max_rows = 10

# %%
allyears = pd.read_csv('allyears.csv.gz')
df_numbers = allyears.dropna().set_index(['name', 'sex']).sort_values('number', ascending = False)

# %%
#male names by popularity
male_names_by_number = np.array(pd.Series.unique(allyears_by_sex.loc['M'].sort_values('number', ascending = False).reset_index().name))

# %%
#female names by popularity
female_names_by_number = np.array(pd.Series.unique(allyears_by_sex.loc['F'].sort_values('number', ascending = False).reset_index().name))

# %%
#find unique values among female and male names

unique_names = set(np.intersect1d(male_names_by_number, female_names_by_number))

# %%
#function for getting total number by name and sex
def get_number(sex, name):
    number = df_numbers.loc[(name, sex)].number.sum()
    return [sex, name, number]

# %%
#get total number by name for male
male_list = []
for name in unique_names:
    result.append(get_number('M', name))
# Out:
# /srv/conda/envs/notebook/lib/python3.6/site-packages/ipykernel_launcher.py:2: PerformanceWarning: indexing past lexsort depth may impact performance.

# %%
#get total number by name for female
female_list = [get_number('F', name) for name in unique_names]
# Out:
# /srv/conda/envs/notebook/lib/python3.6/site-packages/ipykernel_launcher.py:2: PerformanceWarning: indexing past lexsort depth may impact performance.

# %%
#merge female_list and male_list
data = male_list + female_list

# %%
#data to DataFrame
df_with_total_numbers = pd.DataFrame(data, columns=['sex', 'name', 'number']).sort_values('number', ascending = False).set_index(['sex', 'name'])

# %%
#function for checking if name is unisex
def if_unisex(name):
    return 0.5 < df_with_total_numbers.loc[('M', name)].number / df_with_total_numbers.loc[('F', name)].number < 2

# %%
#find top 10 unisex names
unisex_names = set()
for name in unique_names:
    if len(unisex_names) <= 9:
        if if_unisex(name):
            unisex_names.add(name)
    else:
        break
