# %% [markdown]
# # [Sourse of tasks](https://www.theguardian.com/sport/2016/aug/05/rio-2016-big-olympics-quiz-games)

# %%
import pandas as pd

# %%
olympics = pd.read_csv('olympics.csv', skiprows = 4)
olympics.head(1)
# Out:
#      City  Edition     Sport Discipline        Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming  HAJOS, Alfred  HUN    Men
#
#             Event Event_gender Medal
# 0  100m freestyle            M  Gold

# %% [markdown]
# # Additional questions
# ## #19. Golf is back at the Olympics this year. When did it last feature?

# %%
data = olympics[olympics.Sport == 'Golf']
data.head(1)
# Out:
#       City  Edition Sport Discipline                     Athlete  NOC Gender  \
# 413  Paris     1900  Golf       Golf  ROBERTSON, David Donaldson  GBR    Men
#
#           Event Event_gender   Medal
# 413  individual            M  Bronze

# %%
data.Edition.max()
# Out:
# 1904

# %% [markdown]
# ## #23. Women first competed in the modern Olympics in 1900 but only in 'ladylike sports'. Which three?

# %%
data = olympics[(olympics.Edition == 1900) & (olympics.Event_gender == 'W')]
data.Sport.unique()
# Out:
# array(['Golf', 'Tennis'], dtype=object)

# %% [markdown]
# *Women competed in three type of sports: Golf, Tennis and Sailing, yet they won medals only in Golf and Tennis, which is why answer slightly differs from the right answer on the web site.*
